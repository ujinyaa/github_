# %%
import pandas as pd
import numpy as np
file_path = "C:\\Users\\LYJ\\Desktop\\CODE_HOME\\리메셀\\india geospatial\\cities_r2.csv"
data = pd.read_csv(file_path)
data.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
data.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# ...

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
data['lattitude'] = data['location'].apply(lambda x: x.split(',')[0])
data['longitude'] = data['location'].apply(lambda x: x.split(',')[1])
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data['lattitude'] = data['location'].apply(lambda x: x.split(',')[0])
#       2 data['longitude'] = data['location'].apply(lambda x: x.split(',')[1])
#       3 data.head(5)
#
# NameError: name 'data' is not defined

# %%
top_pop_cities = data.sort_values(by='population_total',ascending=False)
top20_populated_cities=top_pop_cities.head(20)
top20_populated_cities
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 141              Delhi            7    NCT OF DELHI         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 7            Ahmadabad           24         GUJARAT          7
# 119            Chennai           33      TAMIL NADU          2
# 274            Kolkata           19     WEST BENGAL         16
# 449              Surat           24         GUJARAT         25
# 380               Pune           27     MAHARASHTRA         25
# 225             Jaipur            8       RAJASTHAN         12
# 288            Lucknow            9   UTTAR PRADESH         26
# 251             Kanpur            9   UTTAR PRADESH         33
# 334             Nagpur           27     MAHARASHTRA          9
# 221             Indore           23  MADHYA PRADESH         22
# ...

# %%
from IPython.display import display

# %%
top20_female = data.nlargest(20, 'sex_ratio')[['name_of_city','population_total', 'population_female','sex_ratio']]
display(top20_female)
# Out:
#             name_of_city  population_total  population_female  sex_ratio
# 278           Kozhikode             432097             225603       1093
# 275              Kollam             349033             180957       1077
# 14            Alappuzha             174164              90276       1076
# 461            Thrissur             315596             163597       1076
# 459  Thiruvananthapuram             752490             387833       1064
# 220              Imphal             264986             136055       1055
# 358            Palakkad             131019              67186       1053
# 245            Kakinada             312255             159659       1046
# 378          Puducherry             241773             123568       1045
# 430            Shillong             143007              72979       1042
# 488        Vizianagaram             227533             115937       1039
# 333           Nagercoil             224329             114197       1037
# ...

# %%
from matplotlib import pyplot as plt
# import seaborn as sns
# %matplotlib inline

from matplotlib import cm
from matplotlib.dates import date2num
from mpl_toolkits.basemap import Basemap

import matplotlib.cm as cm

# %%
plt.subplots(figsize=(20, 15))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)

map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

#인구별 상위 도시 20개
longitude=np.array(top20_populated_cities['longitude'].apply(lambda x: float(x.split(',')[1]))) ## 경도
lattitude=np.array(top20_populated_cities['lattitude'].apply(lambda x: float(x.split(',')[0]))) ## 위도 
total_population=np.array(top20_populated_cities['population_total'])
city_name=np.array(top20_populated_cities['name_of_city'])

x, y = map(longitude, lattitude)
population_sizes = top20_populated_cities["population_total"].apply(lambda x: int(x / 5000))
plt.scatter(x, y, s=population_sizes, marker="o", c=population_sizes, cmap=cm.Dark2, alpha=0.8)

for ncs, xpt, ypt in zip(city_name, x, y):
    plt.text(xpt+6000, ypt+3000, ncs, fontsize=10, fontweight='bold')

plt.title('Top 20 Populated Cities and Female Dominated Cities in India', fontsize=20)
plt.show()

# # 여성 비율이 더 높은 상위 20개 도시
# longitude_female = np.array(top20_female['longitude'].apply(lambda x: float(x.split(',')[1])))
# lattitude_female = np.array(top20_female['lattitude'].apply(lambda x: float(x.split(',')[0])))
# total_population=np.array(top20_populated_cities['top 20 female ratio'])
# city_name_female = np.array(top20_female['name_of_city'])

# x_female, y_female = map(longitude_female, lattitude_female)
# plt.scatter(x, y, s=top20_female, marker="o", c=population_sizes, cmap=cm.Dark2, alpha=0.5)


# for ncs, xpt, ypt in zip(city_name_female, x_female, y_female):
#     plt.text(xpt + 6000, ypt + 3000, ncs, fontsize=10, fontweight='bold')

# plt.title('Top 20 Populated Cities and Female Dominated Cities in India', fontsize=20)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       7 map.drawcoastlines ()
#       9 #인구별 상위 도시 20개
# ---> 10 longitude=np.array(top20_populated_cities['longitude'].apply(lambda x: float(x.split(',')[1]))) ## 경도
#      11 lattitude=np.array(top20_populated_cities['lattitude'].apply(lambda x: float(x.split(',')[0]))) ## 위도
#      12 total_population=np.array(top20_populated_cities['population_total'])
#
# NameError: name 'np' is not defined

# %%
def map_draw(X):
    map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)
    map.drawmapboundary ()
    map.drawcountries ()
    map.drawcoastlines ()

    longitude=np.array(X['longitude'])
    lattitude=np.array(X['lattitude'])
    K=np.array(x['population_total'])
    city_name=np.array(X['name_of_city'])
    
    x, y = map(longitude, lattitude)
    population_sizes = top20_populated_cities["population_total"].apply(lambda x: int(x / 5000))
    plt.scatter(x, y, s=population_sizes, marker="o", c=population_sizes, cmap=cm.Dark2, alpha=0.8)

    for ncs, xpt, ypt in zip(city_name, x, y):
        plt.text(xpt+6000, ypt+3000, ncs, fontsize=10, fontweight='bold')
        

    

    

plt.subplots(figsize=(20, 15))
plt.subplot(1, 2, 1)


x, y = map(longitude, lattitude)
population_sizes = top20_populated_cities["population_total"].apply(lambda x: int(x / 5000))
plt.scatter(x, y, s=population_sizes, marker="o", c=population_sizes, cmap=cm.Dark2, alpha=0.8)

for ncs, xpt, ypt in zip(city_name, x, y):
    plt.text(xpt+6000, ypt+3000, ncs, fontsize=10, fontweight='bold')
plt.title('Top 20 Populated Cities',fontsize=20)

plt.subplot(1, 2, 2)
longitude_female = np.array(top20_female['longitude'])
lattitude_female = np.array(top20_female['lattitude'])
total_population=np.array(top20_populated_cities['top 20 female ratio'])
city_name_female = np.array(top20_female['name_of_city'])

x_female, y_female = map(longitude_female, lattitude_female)
plt.scatter(x, y, s=top20_female, marker="o", c=population_sizes, cmap=cm.Dark2, alpha=0.5)

for ncs, xpt, ypt in zip(city_name_female, x_female, y_female):
    plt.text(xpt + 6000, ypt + 3000, ncs, fontsize=10, fontweight='bold')

plt.title('Top 20 Female Dominated Cities in India', fontsize=20)
plt.show()

# %% [markdown]
# 상위 20개 인구 토탈 , 여자 인구 지도 비교
# -> 화장품 유통 도시 추측

# %%
top20_literates_female = data.nlargest(20, 'sex_ratio')[['name_of_city','population_total', 'population_female','sex_ratio']]
display(top20_female)

# %% [markdown]
# 문맹률 상위 20개 비교 -> 상위 20 (문맹률과 여자 인구) 상관관계 비교

# %% [markdown]
# https://www.kaggle.com/code/eswarchandt/geospatial-analysis-india
