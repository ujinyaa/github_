# %% [markdown]
# 1. https://www.kaggle.com/datasets/shyamgupta196/apps-user-used-the-most
#
# WHATSAPP - 인도시장에서의 카카오톡
# -> 왓츠앱이 많이 쓰이는 앱이다...를 보여주는 데이터셋

# %%
import pandas as pd
import numpy as  np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules

# %%
data = pd.read_csv(r'C:\Users\LYJ\Desktop\CODE_HOME\리메셀\whatsapp\apriori_data.csv')
data.head()
data['AppName'].dtypes
# Out:
# dtype('O')

# %%
df = list(data["AppName"].apply(lambda x:x.split(',')))
te = TransactionEncoder()
te_data = te.fit(df).transform(df)
data = pd.DataFrame(te_data,columns=te.columns_)
data
# Out:
#     Amazon  Amazon Prime  Discord  Facebook  Hotstar  Instagram   Meet  \
# 0     True         False    False     False    False       True   True
# 1    False         False     True     False    False       True  False
# 2     True          True    False      True    False       True  False
# 3    False         False    False     False    False      False   True
# 4    False         False    False     False    False       True   True
# 5    False         False    False     False    False       True   True
# 6    False         False    False     False    False       True   True
# 7    False         False    False     False    False       True  False
# 8    False          True    False      True    False      False   True
# 9    False         False    False     False    False       True   True
# 10   False         False    False     False    False       True  False
# 11   False         False    False     False    False      False  False
# ...

# %% [markdown]
# apriori antacedent -> 적용 못함
# whatsapp사용 자체의 빈도를 보는거지
# whatsapp -> othter app의 연관 관계를 보렴 ㄴ antecedent, consequent를 찾아봐야됨
#
# -> in this EDA, we use associatio rule mining to find out the relationship between whatsapps and the other app asscociation in millanions generation

# %% [markdown]
# 2. 인도 인구
#
# 인도 인구의 평균 연령대 나이값  == 28세 , 7-8억명
#
# https://www.kaggle.com/code/timmofeyy/eda-india-population

# %% [markdown]
# 3. 가처분 소득이 많은 계층에서 증가, 절대 빈곤층이 줄어가고 있다.

# %% [markdown]
# 4. 지리적 특징
# 또한 인도라는 국가의 지리적 특성을 파악했을때, 땅이 크고 길기 때문에 여러 기후가 존재한다. (지역별 특징에 따라서 썬크림 등 사용하는 화장품이 다를수 있음, 건조한 기후, 일교차가 큰 기후 등 다양할 수 있음)
#
# 크리셋, 인도 기후 (자외선) 등을 고려했을때 선크림, 클렌저 등 수출 가능성 강조

# %% [markdown]
# 5. 뭄바이 (리메세 창고 위치 )
#
# 다) 인도의 지리적 특징  -> 뭄바이 (항구, 공항 위치),  동부가 산 많아서 택배 안됨 .. //

# %% [markdown]
# 6. 인도의 사회/문화적 특수성 + 추가 자료조사
# 인도쌀, 난 -> 밀가루 -> 여드름 ( ? ,,치료제 되는 화장품)

# %% [markdown]
# https://docs.google.com/document/d/1SWIfKY0QeCh4wBSTulZGw7RLC2Pjr-tsN2o0VlgboQQ/edit?usp=sharing
