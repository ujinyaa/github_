# %%
import pandas as pd

file_path = '2023년도+폐기물+재활용실적+및+업체현황.xlsx'

df = pd.ExcelFile(file_path, engine='openpyxl')
sheet_names = df.sheet_names 

print("시트 목록:", sheet_names)

sheets = {}
for name in sheet_names:
    sheets[name] = df.parse(name)
    print(f"✅ '{name}' 시트 미리보기:")
    print(sheets[name].head())
# Out:
# 시트 목록: ['표지(1)', '목차(2)', '자료의 이해(3)', '업체현황(4)', '업체현황(5)', '업체현황(6)', '업체현황(7)', '업체현황(8)', '업체현황(9)', '재활용실적(10)', '재활용실적(11)', '재활용실적(12)', '재활용실적(13)', '재활용실적(14)', '재활용실적(15)', '재활용실적(16) 일반 코드별', '재활용실적(17) 지정 코드별', '재활용실적(18) 생활 코드별', '재활용실적(19) 일반 대분류', '재활용실적(20) 지정 대분류', '재활용실적(21) 생활 대분류', '재활용실적(22) 지역별 전국전체', '재활용실적(23) 지역별 시도', '재활용실적(24) 처리방법별 처리량', '재활용실적(25) 처리방법별 폐기물구분', '부록 업체정보_허가_코드별_일반', '부록 업체정보_허가_코드별_지정', '부록 업체정보_허가_코드별_생활', '부록 업체정보_신고_코드별 일반', '부록 업체정보_신고_코드별 지정', '부록 업체정보_신고_코드별 생활', '부록 업체정보_지역별', '부록 폐기물의 종류별 세부분류', '부록 별지 제52호서식']
# ✅ '표지(1)' 시트 미리보기:
#   Unnamed: 0  Unnamed: 1            Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0        NaN         NaN                   NaN         NaN         NaN
# 1        NaN         NaN           발 간 등 록 번 호         NaN         NaN
# 2        NaN         NaN  11-B552584-000002-10         NaN         NaN
# 3        NaN         NaN                   NaN         NaN         NaN
# 4        NaN         NaN                   NaN         NaN         NaN
#
#    Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8              Unnamed: 9
# 0         NaN                    NaN         NaN                     NaN
# 1         NaN        NaN         NaN         NaN   K-eco(2024)-자원순환PE-36
# 2         NaN        NaN         NaN         NaN                     NaN
# 3         NaN        NaN         NaN         NaN                     NaN
# 4         NaN        NaN         NaN         NaN                     NaN
# ✅ '목차(2)' 시트 미리보기:
#        Unnamed: 0                       Unnamed: 1
# 0        목    차                                NaN
# 1             NaN                              NaN
# 2      Ⅰ. 자료의 이해   …………………………………………………………………………………
# 3             NaN                              NaN
# 4   Ⅱ.  폐기물 재활용실적  …………………………………………………………………………………
# ✅ '자료의 이해(3)' 시트 미리보기:
#                                            Ⅰ. 자료의 이해  Unnamed: 1 Unnamed: 2
# 0                                                NaN         NaN        NaN
# 1                                              O 개 요         NaN        NaN
# 2                                                NaN         NaN        NaN
# 3                                         - 통계작성 목적          NaN        NaN
# 4            o 재활용 관련 업체의 현황, 연간 재활용실적을 파악하여 재활용산...         NaN        NaN
# ✅ '업체현황(4)' 시트 미리보기:
#         Ⅱ. 폐기물 재활용실적 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1        1. 재활용업체 현황        NaN        NaN        NaN        NaN        NaN
# 2    (1) 등록형태별 업체 현황        NaN        NaN        NaN        NaN        NaN
# 3                NaN        NaN        NaN        NaN        NaN        NaN
# 4                NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN
# ✅ '업체현황(5)' 시트 미리보기:
#    Unnamed: 0            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN      (2) 폐기물분류별 업체 현황        NaN        NaN        NaN
# 1         NaN                   NaN        NaN        NaN        NaN
# 2         NaN     O 폐기물종류별 재활용업체 현황        NaN        NaN        NaN
# 3         NaN                   NaN        NaN        NaN        NaN
# 4         NaN                    구분          계   사업장일반폐기물      지정폐기물
#
#   Unnamed: 5  Unnamed: 6 Unnamed: 7
# 0        NaN         NaN        NaN
# 1        NaN         NaN
# 2        NaN         NaN        NaN
# 3  (단위 : 개소)         NaN        NaN
# 4      생활폐기물         NaN        NaN
# ✅ '업체현황(6)' 시트 미리보기:
#    Unnamed: 0          Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN    O 연도별 재활용업체 증감추이        NaN        NaN        NaN        NaN
# 1         NaN           (단위 : 개소)        NaN        NaN        NaN        NaN
# 2         NaN                  구분        NaN        '11        '12        '13
# 3         NaN         업체현황(가동업체수)        NaN       3916       4346       5180
# 4         NaN  (A)+(B) 또는 (a)+(b)        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2        '14        '15        '16        '17         '18         '19
# 3       5372       5432       6085       5472        5972        6557
# 4        NaN        NaN        NaN        NaN         NaN         NaN
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         '20         '21         '22         '23
# 3        6535        6720        6910        7221
# 4         NaN         NaN         NaN         NaN
# ✅ '업체현황(7)' 시트 미리보기:
#    Unnamed: 0    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0         NaN     (3) 종업원 수        NaN        NaN        NaN
# 1         NaN           NaN        NaN        NaN        NaN
# 2         NaN     O 종업원의 분포        NaN        NaN        NaN
# 3         NaN           NaN        NaN        NaN        NaN
# 4         NaN          종업원수   ‘22년 업체수   ‘23년 업체수     증감수(%)
# ✅ '업체현황(8)' 시트 미리보기:
#   Unnamed: 0             Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0        NaN         (4) 재활용제품 판매추이        NaN        NaN        NaN
# 1        NaN                    NaN        NaN        NaN        NaN
# 2        NaN     O 허가 및 신고업체 재활용 현황        NaN        NaN        NaN
# 3        NaN                    NaN        NaN        NaN        NaN
# 4        NaN       (단위 : 개소, 톤, 천원)        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
# ✅ '업체현황(9)' 시트 미리보기:
#    Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0         NaN   O 재활용업체 판매액 분포        NaN        NaN         NaN
# 1         NaN              NaN        NaN        NaN         NaN
# 2         NaN             판매금액      해당업체수     구성비(%)         NaN
# 3         NaN   0(판매금액 없음, 무상)       2441  33.804182         NaN
# 4         NaN  1원 이상 ∼ 1천만원 미만        327   4.528459         NaN
#
#           Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  O 연도별 재활용량·판매액 추이        NaN        NaN        NaN        NaN         NaN
# 1                NaN        NaN        NaN        NaN        NaN         NaN
# 2                NaN        NaN        NaN        NaN        NaN         NaN
# 3                NaN        NaN        NaN        NaN        NaN         NaN
# 4                NaN        NaN        NaN        NaN        NaN         NaN
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 17 Unnamed: 18
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
# ✅ '재활용실적(10)' 시트 미리보기:
#    Unnamed: 0     2. 2023년 재활용실적 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN                NaN        NaN        NaN        NaN        NaN
# 1         NaN           (1) 총괄현황        NaN        NaN        NaN        NaN
# 2         NaN                NaN        NaN        NaN        NaN        NaN
# 3         NaN     O 주요폐기물 재활용 현황        NaN        NaN        NaN        NaN
# 4         NaN                NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ✅ '재활용실적(11)' 시트 미리보기:
#      - 주요 사업장일반폐기물 연도별 재활용 현황         Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                         NaN                NaN        NaN        NaN
# 1                         NaN              2018년        NaN        NaN
# 2                         NaN                NaN        NaN        NaN
# 3                       폐기물종류  재활용\n폐기물량\n(천톤/년)  재활용제품 판매량        NaN
# 4                         NaN                NaN       천톤/년        구성비
#
#    Unnamed: 4         Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0         NaN                NaN        NaN        NaN         NaN
# 1         NaN              2019년        NaN        NaN         NaN
# 2         NaN                NaN        NaN        NaN         NaN
# 3         NaN  재활용\n폐기물량\n(천톤/년)  재활용제품 판매량        NaN         NaN
# 4         NaN                NaN       천톤/년        구성비         NaN
#
#           Unnamed: 9  ... Unnamed: 14 Unnamed: 15  Unnamed: 16  \
# 0                NaN  ...         NaN         NaN          NaN
# 1              2020년  ...         NaN         NaN          NaN
# 2                NaN  ...         NaN         NaN          NaN
# 3  재활용\n폐기물량\n(천톤/년)  ...   재활용제품 판매량         NaN          NaN
# 4                NaN  ...        천톤/년         구성비          NaN
#
#          Unnamed: 17 Unnamed: 18 Unnamed: 19  Unnamed: 20        Unnamed: 21  \
# 0                NaN         NaN         NaN          NaN                NaN
# 1              2022년         NaN         NaN          NaN              2023년
# 2                NaN         NaN         NaN          NaN                NaN
# 3  재활용\n폐기물량\n(천톤/년)   재활용제품 판매량         NaN          NaN  재활용\n폐기물량\n(천톤/년)
# 4                NaN        천톤/년         구성비          NaN                NaN
#
#   Unnamed: 22 Unnamed: 23
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3   재활용제품 판매량         NaN
# 4        천톤/년         구성비
#
# [5 rows x 24 columns]
# ✅ '재활용실적(12)' 시트 미리보기:
#    Unnamed: 0 O 지정폐기물 재활용 현황 Unnamed: 2   Unnamed: 3 Unnamed: 4  \
# 0         NaN            NaN        NaN          NaN        NaN
# 1         NaN          폐기물종류      가동업체수     재활용 폐기물량        NaN
# 2         NaN            NaN        NaN          톤/년     구성비(%)
# 3         NaN              계       1801  4421782.097        100
# 4         NaN      폐합성고분자화합물        101    30915.543   0.699165
#
#       Unnamed: 5 Unnamed: 6
# 0            NaN        NaN
# 1      재활용제품 판매량        NaN
# 2            톤/년     구성비(%)
# 3  3343258.36011        100
# 4      46297.701   1.384808
# ✅ '재활용실적(13)' 시트 미리보기:
#      - 주요 지정폐기물 연도별 재활용 현황         Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                      NaN                NaN        NaN        NaN
# 1                      NaN              2018년        NaN        NaN
# 2                      NaN                NaN        NaN        NaN
# 3                    폐기물종류  재활용\n폐기물량\n(천톤/년)  재활용제품 판매량        NaN
# 4                      NaN                NaN       천톤/년        구성비
#
#    Unnamed: 4         Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0         NaN                NaN        NaN        NaN         NaN
# 1         NaN              2019년        NaN        NaN         NaN
# 2         NaN                NaN        NaN        NaN         NaN
# 3         NaN  재활용\n폐기물량\n(천톤/년)  재활용제품 판매량        NaN         NaN
# 4         NaN                NaN       천톤/년        구성비         NaN
#
#           Unnamed: 9  ... Unnamed: 14 Unnamed: 15  Unnamed: 16  \
# 0                NaN  ...         NaN         NaN          NaN
# 1              2020년  ...         NaN         NaN          NaN
# 2                NaN  ...         NaN         NaN          NaN
# 3  재활용\n폐기물량\n(천톤/년)  ...   재활용제품 판매량         NaN          NaN
# 4                NaN  ...        천톤/년         구성비          NaN
#
#          Unnamed: 17 Unnamed: 18 Unnamed: 19  Unnamed: 20        Unnamed: 21  \
# 0                NaN         NaN         NaN          NaN                NaN
# 1              2022년         NaN         NaN          NaN              2023년
# 2                NaN         NaN         NaN          NaN                NaN
# 3  재활용\n폐기물량\n(천톤/년)   재활용제품 판매량         NaN          NaN  재활용\n폐기물량\n(천톤/년)
# 4                NaN        천톤/년         구성비          NaN                NaN
#
#   Unnamed: 22 Unnamed: 23
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3   재활용제품 판매량         NaN
# 4        천톤/년         구성비
#
# [5 rows x 24 columns]
# ✅ '재활용실적(14)' 시트 미리보기:
#    Unnamed: 0 O 생활폐기물 재활용 현황 Unnamed: 2    Unnamed: 3 Unnamed: 4   Unnamed: 5  \
# 0         NaN            NaN        NaN           NaN        NaN          NaN
# 1         NaN          폐기물종류      가동업체수      재활용 폐기물량        NaN    재활용제품 판매량
# 2         NaN            NaN        NaN           톤/년     구성비(%)          톤/년
# 3         NaN              계        957  4850044.1728        100  4005463.185
# 4         NaN   종량제봉투 배출 폐기물          5     207999.03   4.288601     83821.47
#
#   Unnamed: 6
# 0        NaN
# 1        NaN
# 2     구성비(%)
# 3      100.0
# 4   2.092679
# ✅ '재활용실적(15)' 시트 미리보기:
#   - 주요 생활폐기물 연도별 재활용 현황         Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0                   NaN                NaN        NaN        NaN         NaN
# 1                   NaN              2018년        NaN        NaN         NaN
# 2                   NaN                NaN        NaN        NaN         NaN
# 3                 폐기물종류  재활용\n폐기물량\n(천톤/년)  재활용제품 판매량        NaN         NaN
# 4                   NaN                NaN       천톤/년        구성비         NaN
#
#           Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8         Unnamed: 9  \
# 0                NaN        NaN        NaN         NaN                NaN
# 1              2019년        NaN        NaN         NaN              2020년
# 2                NaN        NaN        NaN         NaN                NaN
# 3  재활용\n폐기물량\n(천톤/년)  재활용제품 판매량        NaN         NaN  재활용\n폐기물량\n(천톤/년)
# 4                NaN       천톤/년        구성비         NaN                NaN
#
#    ... Unnamed: 14 Unnamed: 15  Unnamed: 16        Unnamed: 17 Unnamed: 18  \
# 0  ...         NaN         NaN          NaN                NaN         NaN
# 1  ...         NaN         NaN          NaN              2022년         NaN
# 2  ...         NaN         NaN          NaN                NaN         NaN
# 3  ...   재활용제품 판매량         NaN          NaN  재활용\n폐기물량\n(천톤/년)   재활용제품 판매량
# 4  ...        천톤/년         구성비          NaN                NaN        천톤/년
#
#   Unnamed: 19  Unnamed: 20        Unnamed: 21 Unnamed: 22 Unnamed: 23
# 0         NaN          NaN                NaN         NaN         NaN
# 1         NaN          NaN              2023년         NaN         NaN
# 2         NaN          NaN                NaN         NaN         NaN
# 3         NaN          NaN  재활용\n폐기물량\n(천톤/년)   재활용제품 판매량         NaN
# 4         구성비          NaN                NaN        천톤/년         구성비
#
# [5 rows x 24 columns]
# ✅ '재활용실적(16) 일반 코드별' 시트 미리보기:
#                     (2) 폐기물종류별 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                          NaN        NaN        NaN        NaN        NaN
# 1                   O 코드별 세부현황        NaN        NaN        NaN        NaN
# 2            - 사업장일반폐기물 재활용 현황        NaN        NaN        NaN        NaN
# 3                          NaN        NaN        NaN        NaN        NaN
# 4             (단위 : 개소, 톤, 천원)        NaN        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
# ✅ '재활용실적(17) 지정 코드별' 시트 미리보기:
#                  Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0            - 지정폐기물 재활용 현황        NaN        NaN        NaN        NaN
# 1                       NaN        NaN        NaN        NaN        NaN
# 2          (단위 : 개소, 톤, 천원)        NaN        NaN        NaN        NaN
# 3          재활용 폐기물종류(코드번호별)        NaN        NaN        NaN         총계
# 4                       NaN        NaN        NaN        NaN    가동\n업체수
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN       허가업체        NaN         NaN
# 4  재활용\n폐기물량        판매량       판매금액    가동\n업체수  재활용\n폐기물량         판매량
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN        신고업체         NaN         NaN         NaN
# 4        판매금액     가동\n업체수   재활용\n폐기물량         판매량        판매금액
# ✅ '재활용실적(18) 생활 코드별' 시트 미리보기:
#                  Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0            - 생활폐기물 재활용 현황        NaN         NaN        NaN        NaN
# 1                       NaN        NaN         NaN        NaN        NaN
# 2          (단위 : 개소, 톤, 천원)        NaN         NaN        NaN        NaN
# 3          재활용 폐기물종류(코드번호별)        NaN         NaN         총계        NaN
# 4                       NaN        NaN         NaN    가동\n업체수  재활용\n폐기물량
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN       허가업체        NaN        NaN         NaN
# 4        판매량       판매금액    가동\n업체수  재활용\n폐기물량        판매량        판매금액
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3        신고업체         NaN         NaN         NaN
# 4     가동\n업체수   재활용\n폐기물량         판매량        판매금액
# ✅ '재활용실적(19) 일반 대분류' 시트 미리보기:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0     O 대분류 폐기물종류별 세부현황        NaN        NaN        NaN        NaN
# 1            - 사업장일반폐기물        NaN        NaN        NaN        NaN
# 2                   NaN        NaN        NaN        NaN        NaN
# 3      (단위 : 개소, 톤, 천원)        NaN        NaN        NaN        NaN
# 4             재활용 폐기물종류          계        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4       허가업체        NaN        NaN        NaN       신고업체         NaN
#
#   Unnamed: 11 Unnamed: 12
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
# ✅ '재활용실적(20) 지정 대분류' 시트 미리보기:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0           - 지정폐기물        NaN        NaN        NaN        NaN        NaN
# 1               NaN        NaN        NaN        NaN        NaN        NaN
# 2  (단위 : 개소, 톤, 천원)        NaN        NaN        NaN        NaN        NaN
# 3         재활용 폐기물종류          계        NaN        NaN        NaN       허가업체
# 4               NaN    가동\n업체수  재활용\n폐기물량        판매량       판매금액    가동\n업체수
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN         NaN
# 3        NaN        NaN        NaN       신고업체         NaN         NaN
# 4  재활용\n폐기물량        판매량       판매금액    가동\n업체수   재활용\n폐기물량         판매량
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4        판매금액
# ✅ '재활용실적(21) 생활 대분류' 시트 미리보기:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0           - 생활폐기물        NaN        NaN        NaN        NaN        NaN
# 1               NaN        NaN        NaN        NaN        NaN        NaN
# 2  (단위 : 개소, 톤, 천원)        NaN        NaN        NaN        NaN        NaN
# 3         재활용 폐기물종류          계        NaN        NaN        NaN       허가업체
# 4               NaN    가동\n업체수  재활용\n폐기물량        판매량       판매금액    가동\n업체수
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN         NaN
# 3        NaN        NaN        NaN       신고업체         NaN         NaN
# 4  재활용\n폐기물량        판매량       판매금액    가동\n업체수   재활용\n폐기물량         판매량
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4        판매금액
# ✅ '재활용실적(22) 지역별 전국전체' 시트 미리보기:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          (3) 시ㆍ도별        NaN        NaN        NaN        NaN        NaN
# 1              O 전국        NaN        NaN        NaN        NaN        NaN
# 2               NaN        NaN        NaN        NaN        NaN        NaN
# 3  (단위 : 개소, 톤, 천원)        NaN        NaN        NaN        NaN        NaN
# 4                시도          계        NaN        NaN        NaN       허가업체
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN         NaN
# 4        NaN        NaN        NaN       신고업체         NaN         NaN
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ✅ '재활용실적(23) 지역별 시도' 시트 미리보기:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          O 시 · 도별        NaN        NaN        NaN        NaN        NaN
# 1               NaN        NaN        NaN        NaN        NaN        NaN
# 2  (단위 : 개소, 톤, 천원)        NaN        NaN        NaN        NaN        NaN
# 3                시도         구분        NaN          계        NaN        NaN
# 4               NaN        NaN        NaN    가동\n업체수  재활용\n폐기물량        판매량
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN         NaN
# 3        NaN       허가업체        NaN        NaN         NaN        신고업체
# 4       판매금액    가동\n업체수  재활용\n폐기물량        판매량        판매금액     가동\n업체수
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4   재활용\n폐기물량         판매량        판매금액
# ✅ '재활용실적(24) 처리방법별 처리량' 시트 미리보기:
#    Unnamed: 0              Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0         NaN           (4) 재활용 처리방법별        NaN        NaN         NaN
# 1         NaN     O 자가 및 위탁 처리방법별 처리량        NaN        NaN         NaN
# 2         NaN                     NaN        NaN        NaN         NaN
# 3         NaN                     NaN        NaN        NaN         NaN
# 4         NaN                 처리방법 구분          계      원형재사용  수리∙수선\n재사용
#
#   Unnamed: 5 Unnamed: 6    Unnamed: 7 Unnamed: 8      Unnamed: 9 Unnamed: 10  \
# 0        NaN        NaN           NaN        NaN             NaN         NaN
# 1        NaN        NaN           NaN        NaN             NaN         NaN
# 2        NaN        NaN           NaN        NaN             NaN         NaN
# 3        NaN        NaN           NaN        NaN             NaN         NaN
# 4      원료 제조    직접 제품제조  농업생산\n활동에 사용  토질개선에\n사용  성토재∙복토재 등으로 사용  직접 \n에너지회수
#
#       Unnamed: 11   Unnamed: 12                 Unnamed: 13   Unnamed: 14
# 0             NaN           NaN                         NaN           NaN
# 1             NaN           NaN                         NaN           NaN
# 2             NaN           NaN                         NaN           NaN
# 3             NaN           NaN                         NaN  (단위 : 톤, 개소)
# 4  연료∙고형연료\n제품 제조  중간가공\n폐기물 제조  재활용환경성평가\n승인을 받은\n유형으로 재활용            기타
# ✅ '재활용실적(25) 처리방법별 폐기물구분' 시트 미리보기:
#    Unnamed: 0       Unnamed: 1     Unnamed: 2   Unnamed: 3   Unnamed: 4  \
# 0         NaN     O 폐기물구분별 처리량            NaN          NaN          NaN
# 1         NaN              NaN            NaN          NaN          NaN
# 2         NaN              NaN            NaN          NaN          NaN
# 3         NaN          처리방법 구분              계        원형재사용  수리∙수선 \n재사용
# 4         NaN                계  93304912.4518  6855801.366   454662.134
#
#      Unnamed: 5     Unnamed: 6    Unnamed: 7   Unnamed: 8      Unnamed: 9  \
# 0           NaN            NaN           NaN          NaN             NaN
# 1           NaN            NaN           NaN          NaN             NaN
# 2           NaN            NaN           NaN          NaN             NaN
# 3         원료 제조        직접 제품제조  농업생산\n활동에 사용   토질개선에 \n사용  성토재∙복토재 등으로 사용
# 4  24169530.929  17547123.8728   4432815.374  2490074.568     7337244.908
#
#    Unnamed: 10     Unnamed: 11   Unnamed: 12                 Unnamed: 13  \
# 0          NaN             NaN           NaN                         NaN
# 1          NaN             NaN           NaN                         NaN
# 2          NaN             NaN           NaN                         NaN
# 3   직접 \n에너지회수  연료∙고형연료\n제품 제조  중간가공\n폐기물 제조  재활용환경성평가\n승인을 받은\n유형으로 재활용
# 4  3511736.373     7134858.236  14221601.654                 5149449.037
#
#   Unnamed: 14
# 0         NaN
# 1         NaN
# 2    (단위 : 톤)
# 3          기타
# 4          14
# ✅ '부록 업체정보_허가_코드별_일반' 시트 미리보기:
#                    1. 업체정보 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                      NaN        NaN        NaN        NaN        NaN
# 1          (1) 등록형태 및 폐기물별        NaN        NaN        NaN        NaN
# 2                   O 허가업체        NaN        NaN        NaN        NaN
# 3           - 사업장일반폐기물(허가)        NaN        NaN        NaN        NaN
# 4                      NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN
# ✅ '부록 업체정보_허가_코드별_지정' 시트 미리보기:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0           - 지정폐기물(허가)        NaN        NaN        NaN        NaN
# 1                   NaN        NaN        NaN        NaN        NaN
# 2                 폐기물종류      폐기물코드        업체명  재활용업 등록형태        대표자
# 3             폐합성고분자화합물       0101       강진산업    종합 재활용업        김영진
# 4             폐합성고분자화합물       0101       명성화학    종합 재활용업        유순형
#
#              Unnamed: 5    Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                   NaN           NaN        NaN        NaN
# 1                   NaN           NaN        NaN        NaN
# 2                    주소          전화번호       종업원수       재생제품
# 3   경기 화성시 향남읍 관리 216-2  031-353-7349          1        pet
# 4  경기 화성시 장안면 수촌리 431번지  031-351-0922          3         pp
#
#                 Unnamed: 9
# 0                      NaN
# 1                      NaN
# 2                     처리방법
# 3  (2010)중간가공폐기물 제조(재)(위탁)
# 4                      NaN
# ✅ '부록 업체정보_허가_코드별_생활' 시트 미리보기:
#              Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0           - 생활폐기물(허가)        NaN         NaN        NaN        NaN
# 1                   NaN        NaN         NaN        NaN        NaN
# 2                 폐기물종류      폐기물코드         업체명  재활용업 등록형태        대표자
# 3          종량제봉투 배출 폐기물       9101  청정빛고을 주식회사    종합 재활용업        김호열
# 4          종량제봉투 배출 폐기물       9101   번영환경개발(주)    종합 재활용업        김인숙
#
#                   Unnamed: 5    Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                        NaN           NaN        NaN        NaN
# 1                        NaN           NaN        NaN        NaN
# 2                         주소          전화번호       종업원수       재생제품
# 3  광주 남구 도동길 160 (양과동,위생매립장)  062-675-5664         43       고형연료
# 4    경기 파주시 파주읍 정문로 633-71 -  031-949-2820          0        열회수
#
#                   Unnamed: 9
# 0                        NaN
# 1                        NaN
# 2                       처리방법
# 3  (1009)연료ㆍ고형연료제품 제조(재)(자가)
# 4    (2010)중간가공폐기물 제조(재)(위탁)
# ✅ '부록 업체정보_신고_코드별 일반' 시트 미리보기:
#                 Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                   O 신고업체        NaN          NaN        NaN        NaN
# 1           - 사업장일반폐기물(신고)        NaN          NaN        NaN        NaN
# 2                      NaN        NaN          NaN        NaN        NaN
# 3                    폐기물종류      폐기물코드          업체명  재활용업 등록형태        대표자
# 4                   유기성오니류       5101  조맹래 농장(2농장)  폐기물처리 신고자        조맹래
#
#                               Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                                    NaN        NaN        NaN        NaN
# 1                                    NaN        NaN        NaN        NaN
# 2                                    NaN        NaN        NaN        NaN
# 3                                     주소       전화번호       종업원수       재생제품
# 4  경남 김해시 대동면 대동로 263 대동면 주중리 66-3 (주중리)        NaN          2         오니
#
#               Unnamed: 9
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                   처리방법
# 4  (1006)토질개선에 사용(재)(자가)
# ✅ '부록 업체정보_신고_코드별 지정' 시트 미리보기:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0           - 지정폐기물(신고)        NaN        NaN        NaN        NaN
# 1                   NaN        NaN        NaN        NaN        NaN
# 2                 폐기물종류      폐기물코드        업체명  재활용업 등록형태        대표자
# 3             폐합성고분자화합물       0101       대우비철  폐기물처리 신고자        김점순
# 4             폐합성고분자화합물       0101     한라환경산업  폐기물처리 신고자        양해선
#
#               Unnamed: 5    Unnamed: 6 Unnamed: 7     Unnamed: 8  \
# 0                    NaN           NaN        NaN            NaN
# 1                    NaN           NaN        NaN            NaN
# 2                     주소          전화번호       종업원수           재생제품
# 3   광주 광산구 사암로 776 (도천동)  062-952-2344          3            NaN
# 4  제주 제주시 오남로 132 (오라이동)  064-721-8006          9  고철및금속캔류, 폐전선외
#
#                                  Unnamed: 9
# 0                                       NaN
# 1                                       NaN
# 2                                      처리방법
# 3                   (2010)중간가공폐기물 제조(재)(위탁)
# 4  (2003)원료 제조(재)(위탁), (2004)직접 제품제조(재)(위탁)
# ✅ '부록 업체정보_신고_코드별 생활' 시트 미리보기:
#              Unnamed: 0 Unnamed: 1                     Unnamed: 2 Unnamed: 3  \
# 0           - 생활폐기물(신고)        NaN                            NaN        NaN
# 1                   NaN        NaN                            NaN        NaN
# 2                 폐기물종류      폐기물코드                            업체명  재활용업 등록형태
# 3          종량제봉투 배출 폐기물       9101  송도생활폐기물전처리 및 자원순환시설-인천경제자유구역청  폐기물처리 신고자
# 4          종량제봉투 배출 폐기물       9101                       (주)부산이앤이  폐기물처리 신고자
#
#            Unnamed: 4                          Unnamed: 5    Unnamed: 6  \
# 0                 NaN                                 NaN           NaN
# 1                 NaN                                 NaN           NaN
# 2                 대표자                                  주소          전화번호
# 3  인천광역시장(인천경제자유구역청장)  인천 연수구 인천신항대로892번길 50 (송도동,인천환경공단)  032-899-4932
# 4                대표이사           부산 강서구 생곡산단로52번길 32 (생곡동)  051-899-5734
#
#   Unnamed: 7 Unnamed: 8                 Unnamed: 9
# 0        NaN        NaN                        NaN
# 1        NaN        NaN                        NaN
# 2       종업원수       재생제품                       처리방법
# 3         41       고형연료  (2009)연료ㆍ고형연료제품 제조(재)(위탁)
# 4         60        NaN  (2009)연료ㆍ고형연료제품 제조(재)(위탁)
# ✅ '부록 업체정보_지역별' 시트 미리보기:
#   Unnamed: 0       Unnamed: 1     Unnamed: 2                     Unnamed: 3  \
# 0    (2) 지역별              NaN            NaN                            NaN
# 1        NaN              NaN            NaN                            NaN
# 2         지역              업체명            대표자                             주소
# 3         서울             봉화금속            금이현        서울 구로구 오류동 123 창명주차장내일부
# 4        NaN  강서구시설관리공단 환경관리팀  강서구시설관리공단 이사장  서울 강서구 마곡동 88번지 일원(서남물재생센터 내)
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6   Unnamed: 7  \
# 0           NaN        NaN        NaN          NaN
# 1           NaN        NaN        NaN          NaN
# 2          전화번호       종업원수      폐기물구분         재생제품
# 3           NaN          0      지정폐기물          NaN
# 4  02-2666-3503          0  사업장 일반폐기물  EPR필름류, PET
#
#                                           Unnamed: 8
# 0                                                NaN
# 1                                                NaN
# 2                                               처리방법
# 3                                                NaN
# 4  (1003)원료 제조(재)(자가), (1009)연료ㆍ고형연료제품 제조(재)(자가),...
# ✅ '부록 폐기물의 종류별 세부분류' 시트 미리보기:
#                                   2. 폐기물의 종류별 세부분류       Unnamed: 1  \
# 0                                              NaN              NaN
# 1  폐기물관리법 시행규칙 [별표4](개정 2023.12.28.) 폐기물의 종류별 세부분류              NaN
# 2                                              대분류              NaN
# 3                                         1. 지정폐기물              NaN
# 4                                               01  특정시설에서 발생하는 폐기물
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6 Unnamed: 7
# 0        NaN        NaN        NaN         NaN         NaN        NaN
# 1        NaN        NaN        NaN         NaN         NaN        NaN
# 2        중분류        NaN        세분류         NaN         NaN        NaN
# 3        NaN        NaN        NaN         NaN         NaN        NaN
# 4      01-01  폐합성고분자화합물   01-01-01  폐폴리에틸렌(PE)         NaN        NaN
# ✅ '부록 별지 제52호서식' 시트 미리보기:
#    3. 폐기물관리법 시행규칙 별지 제52호 서식(개정 2023.5.31.)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                 (     년도) 폐기물 재활용 실적보고서\n      ...        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 1        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 2        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 3        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 4        NaN        NaN        NaN        NaN        NaN        NaN  ...
#
#    Unnamed: 27 Unnamed: 28  Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 0          NaN         NaN          NaN         NaN         NaN         NaN
# 1          NaN         NaN          NaN         NaN         NaN         NaN
# 2          NaN         NaN          NaN         NaN         NaN         NaN
# 3          NaN         NaN          NaN         NaN         NaN         NaN
# 4       ④성질ㆍ상태         NaN       ⑤재활용방법         NaN    ⑥재활용량(톤)         NaN
#
#        Unnamed: 33 Unnamed: 34  Unnamed: 35  Unnamed: 36
# 0              NaN         NaN          NaN          NaN
# 1              NaN         NaN          NaN          NaN
# 2              NaN         NaN          NaN          NaN
# 3              NaN         NaN          NaN          NaN
# 4  ⑦재활용 제품\n생산량(톤)         NaN      ⑧보관량(톤)          NaN
#
# [5 rows x 37 columns]

# %%
df_permission = df.parse("부록 업체정보_신고_코드별 생활")
print(df_permission.head())
# Out:
#              Unnamed: 0 Unnamed: 1                     Unnamed: 2 Unnamed: 3  \
# 0           - 생활폐기물(신고)        NaN                            NaN        NaN
# 1                   NaN        NaN                            NaN        NaN
# 2                 폐기물종류      폐기물코드                            업체명  재활용업 등록형태
# 3          종량제봉투 배출 폐기물       9101  송도생활폐기물전처리 및 자원순환시설-인천경제자유구역청  폐기물처리 신고자
# 4          종량제봉투 배출 폐기물       9101                       (주)부산이앤이  폐기물처리 신고자
#
#            Unnamed: 4                          Unnamed: 5    Unnamed: 6  \
# 0                 NaN                                 NaN           NaN
# 1                 NaN                                 NaN           NaN
# 2                 대표자                                  주소          전화번호
# 3  인천광역시장(인천경제자유구역청장)  인천 연수구 인천신항대로892번길 50 (송도동,인천환경공단)  032-899-4932
# 4                대표이사           부산 강서구 생곡산단로52번길 32 (생곡동)  051-899-5734
#
#   Unnamed: 7 Unnamed: 8                 Unnamed: 9
# 0        NaN        NaN                        NaN
# 1        NaN        NaN                        NaN
# 2       종업원수       재생제품                       처리방법
# 3         41       고형연료  (2009)연료ㆍ고형연료제품 제조(재)(위탁)
# 4         60        NaN  (2009)연료ㆍ고형연료제품 제조(재)(위탁)

# %%
df_permission = df.parse("부록 업체정보_신고_코드별 생활", header=3)
print(df_permission.columns.tolist())  # 칼럼 이름 다시 확인
# Out:
# ['폐기물종류', '폐기물코드', '업체명', '재활용업 등록형태', '대표자', '주소', '전화번호', '종업원수', '재생제품', '처리방법']

# %%
# 사용할 칼럼 리스트
cols = [
    '폐기물종류', '폐기물코드', '업체명', '재활용업 등록형태',
    '대표자', '주소', '전화번호', '종업원수',
    '재생제품', '처리방법'
]

# 필요한 열만 추출
df_per= df_permission[cols]
df_per.tail()
# Out:
#           폐기물종류  폐기물코드               업체명  재활용업 등록형태        대표자  \
# 549  그 밖의 생활폐기물   9199  제주광역생활자원회수센터 폐기물  폐기물처리 신고자  제주특별자치도지사
# 550  그 밖의 생활폐기물   9199              대영기업  폐기물처리 신고자        김영효
# 551  그 밖의 생활폐기물   9199              대원농장  폐기물처리 신고자        권홍연
# 552  그 밖의 생활폐기물   9199        울산남구지역자활센터  폐기물처리 신고자        서경은
# 553  그 밖의 생활폐기물   9199        울산동구지역자활센터  폐기물처리 신고자        김용식
#
#                                           주소          전화번호  종업원수  \
# 549  제주 제주시 구좌읍 북촌12길 205 (동복리 1157번지 외 1필지)  064-710-6092    82
# 550                      울산 남구 여천로 174 (여천동)  052-260-9944    75
# 551                충북 청원군 현도면 노산리 786(786-1)  042-933-2826     0
# 552                     울산광역시 남구 여천로 12번길 50  052-227-0991    10
# 553                         울산광역시 동구 상진1길 21  052-235-3635     7
#
#                                                   재생제품  \
# 549  PET압축품, PE압축품, PP압축품, PS압축품, 고철, 고철(선별), 기타단일압...
# 550                                                NaN
# 551                                                NaN
# 552                                               아이스팩
# 553                                               아이스팩
#
#                         처리방법
# 549  (1010)중간가공폐기물 제조(재)(자가)
# 550  (2010)중간가공폐기물 제조(재)(위탁)
# 551  (1005)농업생산활동에 사용(재)(자가)
# 552      (2001)원형 재사용(재)(위탁)
# 553   (2002)수리ㆍ수선 재사용(재)(위탁)

# %%
cols_used = ['폐기물종류', '폐기물코드', '업체명', '재활용업 등록형태', '주소', '종업원수']
df_used = df_per[cols_used].copy()

# %% [markdown]
# # 텍스트형 필수 칼럼 결측 제거
# df_used.dropna(subset=['폐기물종류', '업체명', '재활용업 등록형태', '주소'], inplace=True)
#
# # 종업원수 NaN -> 중앙값으로 대체
# df_used['종업원수'] = df_used['종업원수'].fillna(df_used['종업원수'].median())

# %%
def strip_and_count(x):
    if isinstance(x, str):
        original = x
        stripped = x.strip()
        return stripped, original != stripped
    return x, False
changed_count = 0
for col in df_used.select_dtypes(include='object').columns:
    stripped_results = df_used[col].apply(strip_and_count)
    df_used[col] = stripped_results.apply(lambda x: x[0])
    changed_count += stripped_results.map(lambda x: x[1]).sum()

# %%
# 문자형 NaN → '없음' 으로 처리
df_used['전화번호'] = df_per['전화번호'].fillna('없음').astype(str)

# %%
print("✅ 최종 전처리 결과:")
print(df_used.dtypes)
print(df_used.head())
# Out:
# ✅ 최종 전처리 결과:
# 폐기물종류        object
# 폐기물코드         int64
# 업체명          object
# 재활용업 등록형태    object
# 주소           object
# 종업원수          int64
# 전화번호         object
# dtype: object
#           폐기물종류  폐기물코드                            업체명  재활용업 등록형태  \
# 0  종량제봉투 배출 폐기물   9101  송도생활폐기물전처리 및 자원순환시설-인천경제자유구역청  폐기물처리 신고자
# 1  종량제봉투 배출 폐기물   9101                       (주)부산이앤이  폐기물처리 신고자
# 2      음식물류 폐기물   9102                          고인돌농원  폐기물처리 신고자
# 3      음식물류 폐기물   9102                           번영농장  폐기물처리 신고자
# 4      음식물류 폐기물   9102                           금척농장  폐기물처리 신고자
#
#                                    주소  종업원수          전화번호
# 0  인천 연수구 인천신항대로892번길 50 (송도동,인천환경공단)    41  032-899-4932
# 1           부산 강서구 생곡산단로52번길 32 (생곡동)    60  051-899-5734
# 2        전북 부안군 상서면 고인돌로 163-14 (용서리)     0            없음
# 3              제주 제주시 송이길 85-35 (회천동)     2            없음
# 4                 경북 경주시 건천읍 금척리 97-2     1            없음

# %%
from sklearn.preprocessing import LabelEncoder

le_type = LabelEncoder()
le_reg = LabelEncoder()

df_used['폐기물종류_encoded'] = le_type.fit_transform(df_used['폐기물종류'])
df_used['재활용업 등록형태_encoded'] = le_reg.fit_transform(df_used['재활용업 등록형태'])

print("폐기물종류 인코딩 클래스:", le_type.classes_)
print("등록형태 인코딩 클래스:", le_reg.classes_)
# Out:
# 폐기물종류 인코딩 클래스: ['고철 및 금속캔류' '그 밖의 생활폐기물' '동물성 잔재물' '식물성 잔재물' '영농폐기물' '유리병 및 폐유리'
#  '음식물류 폐기물' '조명폐기물' '종량제봉투 배출 폐기물' '폐식용유' '폐의류 및 원단류' '폐전기전자제품' '폐전지류'
#  '폐지류(종이팩을 포함한다)' '폐합성수지']
# 등록형태 인코딩 클래스: ['폐기물처리 신고자']

# %%
# 앞 두 글자를 '지역' 컬럼으로 추출
df_used['지역'] = df_used['주소'].apply(lambda x: str(x)[:2] if pd.notnull(x) else '없음')
print(df_used['지역'].value_counts())
df_used['지역'].nunique()
# Out:
# 지역
# 경기    146
# 경남     49
# 충북     46
# 제주     39
# 인천     38
# 광주     37
# 경북     24
# 울산     18
# 전북     17
# 충남     15
# 부산     15
# 대구     14
# 대전     14
# 강원     11
# 충청     10
# 영동      8
# 청주      7
# 서울      6
# 전남      6
# 구미      6
# 강릉      5
# 안동      5
# 춘천      4
# 음성      3
# 포항      2
# 경상      2
# 봉화      2
# 세종      1
# 창원      1
# 천안      1
# 사무      1
# 보은      1
# Name: count, dtype: int64
# 32

# %% [markdown]
# 1. 폐기물 종류별 개수 비교 (칼럼: 페기물 종류)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 깨짐 방지

plt.figure(figsize=(10, 6))
sns.countplot(data=df_used, x='폐기물종류', order=df_used['폐기물종류'].value_counts().index)
plt.title("신고_생활폐기물 종류별 개수 비교")
plt.xticks(rotation=45)
plt.xlabel("지정폐기물 종류")
plt.ylabel("건수")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 깨짐 방지

plt.figure(figsize=(10, 6))
sns.countplot(data=df_used, x='폐기물코드', order=df_used['폐기물코드'].value_counts().index)
plt.title("신고_생활폐기물 종류별 개수 비교(코드별)")
plt.xticks(rotation=45)
plt.xlabel("지정폐기물 종류")
plt.ylabel("건수")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 깨짐 방지

plt.figure(figsize=(12, 7))
ax = sns.countplot(
    data=df_used,
    x='재활용업 등록형태',
    order=df_used['재활용업 등록형태'].value_counts().index
)

# 제목과 라벨 스타일 개선
plt.title("신고_생활폐기물_재활용업 등록 형태별 개수 비교", fontsize=14)
plt.xlabel("재활용업 등록 형태", fontsize=12)
plt.ylabel("건수", fontsize=12)
plt.xticks(rotation=30, ha='right', fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# 3. 종업원수 비교

# %%
import pandas as pd
import re

# 복사 + 정제
df = df_used.copy()
# 구간 분류 함수
# 분류 함수
def classify_emp(emp):
    try: return ['0~4명', '5~9명', '10~29명', '30~49명', '50~99명', '100명 이상'][
        [int(emp) < 5, int(emp) < 10, int(emp) < 30, int(emp) < 50, int(emp) < 100, int(emp) >= 100].index(True)
    ]
    except:
        for kw, label in [('이상', '100명 이상'), ('100', '50~99명'), ('50', '30~49명'),
                          ('30', '30~49명'), ('10', '10~29명'), ('5', '5~9명'), ('0', '0~4명')]:
            if kw in emp: return label
        return '기타'

df['종업원수_구간'] = df['종업원수'].apply(classify_emp)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 순서 고정
order = ['0~4명', '5~9명', '10~29명', '30~49명', '50~99명', '100명 이상']

plt.figure(figsize=(16, 8))
sns.countplot(data=df, x='지역', hue='종업원수_구간', hue_order=order)

plt.title("생활 폐기물 신고업체 지역별 종업원수 구간 분포", fontsize=14)
plt.xlabel("지역", fontsize=12)
plt.ylabel("사업장 수", fontsize=12)
plt.legend(title="종업원수 구간")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 5.  지역 주소별 개수 비교 (칼럼 : 주소 이용)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 깨짐 방지 설정 (Windows 기준)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 앞 두 글자를 '지역' 컬럼으로 추출
df_used['지역'] = df_used['주소'].apply(lambda x: str(x)[:2] if pd.notnull(x) else '없음')

# 시각화
plt.figure(figsize=(10, 6))
sns.countplot(data=df_used, x='지역', order=df_used['지역'].value_counts().index)
plt.title("신고_생활폐기물 지역별 재활용 업체 개수 비교")
plt.xlabel("지역")
plt.ylabel("업체 수")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
location_map = {
    '서울': '서울특별시',
    '부산': '부산광역시',
    '대구': '대구광역시',
    '인천': '인천광역시',
    '광주': '광주광역시',
    '대전': '대전광역시',
    '울산': '울산광역시',
    '세종': '세종특별자치시',
    '경기': '경기도',
    '강원': '강원도',
    '충북': '충청북도',

    '전북': '전라북도',    '충남': '충청남도',
    '전남': '전라남도',
    '경북': '경상북도',
    '경남': '경상남도',
    '제주': '제주특별자치도'
}
sub_location_map = {
    '충청': '충청북도',  
    '영동': '강원도',
    '청주': '충청북도',
    '구미': '경상북도',
    '강릉': '강원도',
    '안동': '경상북도',
    '춘천': '강원도',
    '음성': '충청북도',
    '포항': '경상북도',
    '경상': '경상남도',   
    '봉화': '경상북도',
    '창원': '경상남도',
    '천안': '충청남도',
    '보은': '충청북도'
}

# 1단계: 17개 기본 매핑
df_used['시도_full'] = df_used['지역'].map(location_map)

# 2단계: NaN인 곳만 보조 매핑 적용
df_used.loc[df_used['시도_full'].isna(), '시도_full'] = df_used['지역'].map(sub_location_map)

print(df_used['시도_full'].value_counts(dropna=False))
# Out:
# 시도_full
# 경기도        146
# 충청북도        67
# 경상남도        52
# 제주특별자치도     39
# 경상북도        39
# 인천광역시       38
# 광주광역시       37
# 강원도         28
# 울산광역시       18
# 전라북도        17
# 충청남도        16
# 부산광역시       15
# 대전광역시       14
# 대구광역시       14
# 전라남도         6
# 서울특별시        6
# 세종특별자치시      1
# NaN          1
# Name: count, dtype: int64

# %%
location_counts = df_used['지역'].map(location_map).value_counts().to_dict()

# %%
import json
from shapely.geometry import shape, Point

# 파일 불러오기
with open('TL_SCCO_CTPRVN.json', encoding='utf-8') as f:
    geo_data = json.load(f)

location = []

for feature in geo_data['features']:
    name = feature['properties']['CTP_KOR_NM']

    # 독도 제외: 경상북도이고 좌표 범위가 독도 위치에 해당하는 경우
    coords_str = json.dumps(feature['geometry'])  # 좌표 문자열화
    if name == "경상북도" and ('131.87' in coords_str or '37.24' in coords_str):
        continue

    geom = shape(feature['geometry'])
    centroid = geom.representative_point()

    # ✅ 수동 위치 조정
    if name == "경기도":
        centroid = Point(centroid.x, centroid.y - 0.2)
    elif name == "서울특별시":
        centroid = Point(centroid.x, centroid.y + 0.04)
    elif name == "전라남도":
        centroid = Point(centroid.x + 1.5, centroid.y + 0.7)
    elif name == "경상남도":
        centroid = Point(centroid.x - 0.6, centroid.y + 0.6)
    elif name == "충청남도":
        centroid = Point(centroid.x, centroid.y - 0.3)
    elif name == "충청북도":
        centroid = Point(centroid.x, centroid.y + 0.2)

    count = location_counts.get(name, 0)

    location.append({
        'name': name,
        'lat': centroid.y,
        'lng': centroid.x,
        'count': count
    })

# %%
from IPython.display import display, HTML

counts = [loc['count'] for loc in location]
vmin, vmax = min(counts), max(counts)

html_final = f"""
<!DOCTYPE html>
<html>
<head>
  <meta charset="utf-8">
  <title>시도별 생활 폐끼물 신고</title>
  <style>
    #map {{
      height: 95vh;
      width: 100%;
    }}
    .label-box {{
      background-color: white;
      padding: 2px 4px;
      border-radius: 4px;
      border: 1px solid #999;
      font-size: 6px;
      color: black;
      white-space: nowrap;
    }}
  </style>
  <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyDsipd6t0T5Q5ykmuSJGets1cRuvr5RnzQ"></script>
</head>
<body>
  <div id="map"></div>
  <script>
    const locations = {json.dumps(location, ensure_ascii=False)};
    const geojson = {geo_data};

    let map;
    function initMap() {{
      map = new google.maps.Map(document.getElementById("map"), {{
        zoom: 5,
        center: {{ lat: 36.5, lng: 127.8 }},
      }});

      const countMap = {json.dumps({loc['name']: loc['count'] for loc in location}, ensure_ascii=False)};

      function getFillColor(count) {{
        if (!count || count === 0) return 'white';
        const ratio = (count - {vmin}) / ({vmax} - {vmin});
        const base = 230;
        const intensity = Math.round(base - ratio * base);
        return 'rgb(255,' + intensity + ',' + intensity + ')';
      }}

      map.data.addGeoJson(geojson);
      map.data.setStyle(function(feature) {{
        const name = feature.getProperty('CTP_KOR_NM');
        const geometry = feature.getGeometry();

        let isDokdo = false;
        geometry.forEachLatLng(function(coord) {{
          if (coord.lat() > 37.2 && coord.lat() < 37.3 && coord.lng() > 131.8 && coord.lng() < 132.1) {{
            isDokdo = true;
          }}
        }});

        if (isDokdo) {{
          return {{
            fillOpacity: 0,
            strokeOpacity: 0
          }};
        }}

        const count = countMap[name] || 0;
        return {{
          fillColor: getFillColor(count),
          fillOpacity: 1.0,
          strokeColor: 'black',
          strokeWeight: 1
        }};
      }});

      // 라벨 생성
      locations.forEach(loc => {{
        const labelDiv = document.createElement('div');
        labelDiv.className = 'label-box';
        labelDiv.innerText = loc.name + ' ' + loc.count + '개';

        const label = new google.maps.OverlayView();
        label.onAdd = function() {{
          const panes = this.getPanes();
          panes.overlayMouseTarget.appendChild(labelDiv);
        }};
        label.draw = function() {{
          const projection = this.getProjection();
          const position = projection.fromLatLngToDivPixel(new google.maps.LatLng(loc.lat, loc.lng));
          labelDiv.style.position = 'absolute';
          labelDiv.style.left = (position.x - labelDiv.offsetWidth / 2) + 'px';
          labelDiv.style.top = (position.y - labelDiv.offsetHeight / 2) + 'px';
        }};
        label.onRemove = function() {{
          labelDiv.parentNode.removeChild(labelDiv);
        }};
        label.setMap(map);
      }});
    }}

    window.onload = initMap;
  </script>
</body>
</html>
"""


# 저장
path = "sue_household.html"
with open(path, "w", encoding="utf-8") as f:
    f.write(html_final)

path
# Out:
# 'sue_household.html'
